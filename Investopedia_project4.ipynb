# %% [markdown]
# ## Stocks Project
#
# I started this project with no knowledge of stocks so hopefully this will be a very good learning experience for me. I would have started with the $250,000 that was provided to us in the game.
# First thing is first, I have downloaded all of the libraries that I would have needed.

# %%
import pandas as pd
from datetime import datetime
import numpy as no
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import yfinance as yf
from pandas_datareader.data import DataReader
from pandas_datareader import data as pdr

# %% [markdown]
# ### Why I chose these companies
# I began my project by choosing 4 companies to invest in. I decided to start with two that I was familiar with and two ETFs. My first choice was Costco, Netflix, and twp Vanguard Group, incs. One is Vanguard Information Technology ETF and the other is Vanguard S&P 500 ETF.
#
# COST => costco   NFLX => Netflix  VGT => Vanguard Information Technology ETF   VOO = > Vanguard S&P 500 ETF
#
# Now that all of my libraries have been imported, I will begin to extract my data.

# %%
#I will be taking data from yahoo
#I will begin my analysis with my first four companies

#I am going to be taking data from 2018 to now 
stop = datetime.fromisoformat('2021-11-17')
start = datetime.fromisoformat('2018-11-17')


costco = DataReader('COST', 'yahoo', start, stop)
netflix = DataReader('NFLX', 'yahoo', start, stop)
vgt = DataReader('VGT', 'yahoo', start, stop)
voo = DataReader('VOO', 'yahoo', start, stop)

# %%
costco.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  755.000000  755.000000  755.000000  755.000000  7.550000e+02
# mean   327.147298  321.741735  324.402106  324.618516  2.335280e+06
# std     71.107525   70.330466   70.595719   70.798624  1.155167e+06
# min    195.330002  189.509995  190.820007  189.990005  5.436000e+05
# 25%    282.585007  279.154999  281.125000  280.844986  1.599900e+06
# 50%    311.970001  306.459991  310.000000  309.579987  1.984300e+06
# 75%    374.639999  368.654999  371.055008  371.495010  2.644250e+06
# max    530.739990  524.510010  527.500000  526.719971  8.822300e+06
#
#         Adj Close
# count  755.000000
# mean   316.131618
# std     74.386705
# min    180.419067
# 25%    268.707809
# 50%    297.763977
# 75%    365.174606
# max    526.719971

# %%
netflix.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  755.000000  755.000000  755.000000  755.000000  7.550000e+02
# mean   437.074211  424.300345  430.595099  430.978092  6.601772e+06
# std    107.517313  105.629061  106.542578  106.601881  4.369012e+06
# min    250.649994  231.229996  233.919998  233.880005  1.144000e+06
# 25%    349.044998  338.784988  343.529999  343.220001  3.826350e+06
# 50%    438.880005  425.179993  429.730011  431.820007  5.398200e+06
# 75%    520.785004  506.014999  514.425018  514.940002  7.825050e+06
# max    700.989990  686.090027  690.000000  691.690002  3.825890e+07
#
#         Adj Close
# count  755.000000
# mean   430.978092
# std    106.601881
# min    233.880005
# 25%    343.220001
# 50%    431.820007
# 75%    514.940002
# max    691.690002

# %%
vgt.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  755.000000  755.000000  755.000000  755.000000  7.550000e+02
# mean   287.521073  282.987060  285.385099  285.465549  6.859291e+05
# std     81.470663   80.828517   81.248558   81.224868  5.084702e+05
# min    159.250000  154.720001  155.940002  154.809998  1.824000e+05
# 25%    215.224998  212.259995  213.625000  213.744995  3.771000e+05
# 50%    268.339996  262.940002  266.049988  264.980011  5.319000e+05
# 75%    361.480011  353.509995  357.465012  358.224991  7.962000e+05
# max    454.299988  450.750000  452.859985  453.480011  4.256000e+06
#
#         Adj Close
# count  755.000000
# mean   282.328759
# std     82.736148
# min    150.424057
# 25%    209.217941
# 50%    260.981232
# 75%    356.721146
# max    453.480011

# %%
voo.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  755.000000  755.000000  755.000000  755.000000  7.550000e+02
# mean   312.483894  308.945470  310.806252  310.870503  3.900860e+06
# std     55.844882   56.198475   56.015357   56.045979  2.585496e+06
# min    210.779999  200.550003  209.630005  204.270004  8.309000e+05
# 25%    267.794998  265.304993  266.804993  266.440002  2.431450e+06
# 50%    296.760010  294.350006  295.489990  295.630005  3.252500e+06
# 75%    358.850006  354.365005  355.959991  356.330002  4.432050e+06
# max    432.760010  430.500000  431.880005  431.410004  2.466930e+07
#
#         Adj Close
# count  755.000000
# mean   304.322518
# std     59.356085
# min    199.485703
# 25%    256.879242
# 50%    288.149261
# 75%    352.720810
# max    431.410004

# %% [markdown]
# ##### Open Stock Prices
#
# Here is just a graph of the open stock prices of the four companies that I bought shares from

# %%
netflix['Open'].plot(label = 'NFLX', figsize = (15,7))
costco['Open'].plot(label = "COST")
vgt['Open'].plot(label = 'VGT')
voo['Open'].plot(label = 'VOO')
plt.title('Stock Prices of Netlix, Costco, VGT, VOO')
plt.legend()

# %% [markdown]
# From the graph above I can see that netflix is the most expesive. For the first week, this is how much each company cost and how many shares of each I bought them for. I included the current price as of 11/19/2021
#
# | Symbol | Description | Current Price | Purchase Price | QTY | Total Value |
# |:--- |: --- |: --- |: --- |: --- |: --- |
# | COST | Costco Wholesale Corp | 533.60 | 526.70 | 50 | 26,680.00 |
# | NFLX | NetFlix Inc | 678.97 | 693.86 | 18 | 12,221.37 |
# | VGT | Vannguard Group, Inc- Vanguard Information Technology ETF  | 457.94 | 451.65 | 100 | 45,794.00 |
# | VOO | CVannguard Group, Inc-Vanguard S&P 500 ETF | 431.96 | 5432.54 | 20 | 8,639.20 |
#
# ##### The total spent is $93334.57

# %% [markdown]
# # Week 1 Analysis
#
# The first thing I want to do is download some more data from similar companies to the ones I have chosen to see if I had made the right choice.
#
# For Costco I decided to check with target, walmart, and Dollar General

# %%
#I am just downloading the data from these 3 
#they all fall in the same sector: Retail Trade
target = DataReader('TGT', 'yahoo', start, stop)
walmart = DataReader('WMT', 'yahoo', start, stop)
dollar_general = DataReader('DG', 'yahoo', start, stop)

# %% [markdown]
# ### Adj Close
# #### This is the closing price after adjustments for all splits and dividend distributions
# I will be graphing the adj close for costco, target, walmart, and dollar general so that I hace a better idea of the overall value of their stocks. It can help me see if Costco was the best choice that made.
#
# If costco is not the best choice, then it will help me make decisions about selling or buying something different.

# %%
costco['Adj Close'].plot(legend = 1, figsize=(10,5), color = "orange")
target['Adj Close'].plot(legend = 1, figsize=(10,5), color = "red")
walmart['Adj Close'].plot(legend = 1, figsize=(10,5), color = "blue")
dollar_general['Adj Close'].plot(legend = 1, figsize=(10,5), color = "green")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Netflix
#
# Next I will comparing the adj close to similar stocks as netflix to see if I have made the right choice with Netflix.
# The three other companies that I will be comparing are Disney(DIS), AMC(AMC), and Discovery (DISCA)

# %%
#I am downloading the data from the three companies
#Although Netflix is in the tech service sector I chose these three 
#companies that belong in the consumer service sector
disney = DataReader('DIS', 'yahoo', start, stop)
AMC = DataReader('AMC', 'yahoo', start, stop)
discovery_a = DataReader('DISCA', 'yahoo', start, stop)

# %%
netflix['Adj Close'].plot(legend = 1, figsize=(10,5), color = "red")
disney['Adj Close'].plot(legend = 1, figsize=(10,5), color = "blue")
AMC['Adj Close'].plot(legend = 1, figsize=(10,5), color = "purple")
discovery_a['Adj Close'].plot(legend = 1, figsize=(10,5), color = "green")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### ETF
#
# First I will be comparing my two ETF to see how they both compare to each other before comparing them to other ETF stocks.

# %%
vgt['Adj Close'].plot(legend = 1, figsize=(10,5), color = "red")
voo['Adj Close'].plot(legend = 1, figsize=(10,5), color = "blue")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# I will be comparing VGT and VOO to Vanguard Mutual Funds -Information Technology Index Fund Admiral Shares (VITAX), iShares - U.S. Technology ETF (IYW), and Vaneck Biotech ETF (BBH)

# %%
#I am gathering data from yahoo for these three companies
#I chose these three because they all fall in the same sector of Miscellaneous 
vitax = DataReader('VITAX', 'yahoo', start, stop)
ishares = DataReader('IYW', 'yahoo', start, stop)
vaneck = DataReader('BBH', 'yahoo', start, stop)

# %%
vgt['Adj Close'].plot(legend = 1, figsize=(10,5), color = "red")
voo['Adj Close'].plot(legend = 1, figsize=(10,5), color = "blue")
vitax['Adj Close'].plot(legend = 1, figsize=(10,5), color = "pink")
ishares['Adj Close'].plot(legend = 1, figsize=(10,5), color = "yellow")
vaneck['Adj Close'].plot(legend = 1, figsize=(10,5), color = "green")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Conclusion based on adj close
#
# Based on the comparisions that I have made I can see that in the four companies' general sectors I can confirm that I have made the right purchasing choices.

# %% [markdown]
# taking a different approach, I am going to put the data for the four companies into a list

# %%
companies = ['COST', 'NFLX', 'VGT', 'VOO']
costco = DataReader('COST', 'yahoo', start, stop)
netflix = DataReader('NFLX', 'yahoo', start, stop)
vgt = DataReader('VGT', 'yahoo', start, stop)
voo = DataReader('VOO', 'yahoo', start, stop)
df = pd.DataFrame()


for comapnies in companies:
    
    try:
        f = pdr.get_data_yahoo(companies,start,stop)
        df[companies] = f['Adj Close']  # select the adjusted close price
    except ValueError:
        print(' No data found')

# %%
#Here I am looking at the stock returns
returns = df.pct_change()
print(returns.head()) #show the stock return from the start
print(returns.tail()) #show the stock return from the end
# Out:
#                 COST      NFLX       VGT       VOO
# Date
# 2018-11-19       NaN       NaN       NaN       NaN
# 2018-11-20 -0.041226 -0.013378 -0.020334 -0.018397
# 2018-11-21 -0.003374 -0.018166  0.008430  0.003336
# 2018-11-23  0.006817 -0.012627 -0.006688 -0.006445
# 2018-11-26 -0.002772  0.010084  0.021708  0.015661
#                 COST      NFLX       VGT       VOO
# Date
# 2021-11-11  0.013195  0.016494  0.005411  0.000328
# 2021-11-12  0.009743  0.038064  0.011980  0.007434
# 2021-11-15  0.005259 -0.004805 -0.001335  0.000466
# 2021-11-16  0.013137  0.011879  0.010428  0.003816
# 2021-11-17 -0.000816  0.006241 -0.004212 -0.002411

# %%
#Here I am checking the monthly stock return of each of my companies so that I can see the comparison
monthly = df.resample('BM').apply(lambda x: x[-1])

month_ret = monthly.pct_change()
print(month_ret)
# Out:
#                 COST      NFLX       VGT       VOO
# Date
# 2018-11-30       NaN       NaN       NaN       NaN
# 2018-12-31 -0.119206 -0.064551 -0.083406 -0.088472
# 2019-01-31  0.053606  0.268400  0.079902  0.079196
# 2019-02-28  0.021902  0.054786  0.073268  0.032499
# 2019-03-29  0.106976 -0.004300  0.040712  0.019256
# 2019-04-30  0.014000  0.039208  0.063699  0.040341
# 2019-05-31 -0.021598 -0.073568 -0.088796 -0.063479
# 2019-06-28  0.103014  0.070030  0.087746  0.069912
# 2019-07-31  0.043026 -0.120685  0.035374  0.014602
# 2019-08-30  0.071770 -0.090529 -0.021937 -0.016405
# 2019-09-30 -0.022561 -0.088953  0.013213  0.019723
# 2019-10-31  0.033479  0.073948  0.037532  0.021827
# 2019-11-29  0.009088  0.094812  0.055938  0.036259
# 2019-12-31 -0.019646  0.028316  0.039673  0.029737
# 2020-01-31  0.039466  0.066508  0.038105 -0.000372
# 2020-02-28 -0.077858  0.069373 -0.072901 -0.080997
# 2020-03-31  0.014192  0.017532 -0.097297 -0.124414
# ...

# %% [markdown]
# ##### Distributions
# In the graphs below I can show the stock returns of each of the companies so that I can compare their distributions in stock behavior over the period of one year.

# %%
returns.hist(bins=50, sharex=True, figsize=(15,10))
plt.show()

# %% [markdown]
# ## Looking at my companies' risk
# I will be chcking the standard deviation and mean for my companies. My goal is to see whether the standard deviation is larger than the mean, if it is, then my stocks can exhibit a higher risk.
# I used this: https://www.investopedia.com/terms/s/standarddeviation.asp in order to better understand the importance of standard deviation compared to mean

# %%
#Here I am getting the mean
comp_mean = returns.mean()
#Here I am getting the variance
comp_var = returns.var()
#Here I am getting the stnd dev
comp_stdev = returns.std()
comp_stdev2 = pd.DataFrame(returns.std())


#Here I am creating a dataframe for mean and for stdev
mean_df = pd.DataFrame(comp_mean)
mean_df2 = mean_df.rename(columns={0: 'mean'})

stdev_df = pd.DataFrame(comp_stdev)
stdev_df2 = stdev_df.rename(columns={0: 'std'})

print(stdev_df2.head())
print(mean_df2.head())
# Out:
#            std
# COST  0.014318
# NFLX  0.024715
# VGT   0.017559
# VOO   0.014358
#           mean
# COST  0.001276
# NFLX  0.001549
# VGT   0.001451
# VOO   0.000911

# %% [markdown]
# ##### What I gathered from the stock returns and stdev and mean
#
# Volatility: The rate at which the price of a stock increases or decreases over a period of time
#
# Standard deviation helps measure the security volatility of stocks. A stock with a greater standard deviation compared to mean can be that it is a volatile stock which a lower standard deviation can mean that the stock is not volatile. A stock that has a low standard deviation is not preferred.
#
# In conclusion, my standard deviation is greater than the means so I can say that my stocks are highly volatile. Because they are volatile, I have the potential to make more money quickly but it does impose a greater risk.

# %% [markdown]
# ### First week thoughts
#
# Based on the information that I have gathered this week I can see that stocks that I have chosen to invest in have a better return than most other companies in similar vectos. I have also made sure to calculate the standard deviation and mean of my stocks' returns and concluded that my stocks have the potential to increase, but it also increases my risk level.
#
# My goal for next week is to continue to calculate the risk that my companies pose and what other companies can help increase my potential to make more money.

# %% [markdown]
# # Week 2

# %% [markdown]
# I will be starting this week by investing in different companies. Before I can invest, I will be doing some research on these companies

# %%
dollar_tree = DataReader('DLTR', 'yahoo', start, stop)
cbre = DataReader('CBRE', 'yahoo', start, stop)
etsy = DataReader('ETSY', 'yahoo', start, stop)
home_depot = DataReader('HD', 'yahoo', start, stop)

# %%
dollar_tree['Open'].plot(label = 'DLTR', figsize = (15,7))
cbre['Open'].plot(label = "CBRE")
etsy['Open'].plot(label = 'ETSY')
home_depot['Open'].plot(label = 'HD')
plt.title('Stock Prices of dollar tree, CBRE, etsy, and home depot')
plt.legend()

# %% [markdown]
# On Monday I invested 50 more shares on COST. Today, Wednesday 11/24, I have decided to invest 20 shares on Home Depot. I will be checking back on my stock tomorrow and Friday to make a decision on what my third trade will be for this week.

# %%
companies = ['COST', 'NFLX', 'VGT', 'VOO', 'HD', 'ETSY']
costco = DataReader('COST', 'yahoo', start, stop)
netflix = DataReader('NFLX', 'yahoo', start, stop)
vgt = DataReader('VGT', 'yahoo', start, stop)
voo = DataReader('VOO', 'yahoo', start, stop)
home_depot = DataReader('HD', 'yahoo', start, stop)
etsy = DataReader('ETSY', 'yahoo', start, stop)
df = pd.DataFrame()


for comapnies in companies:
    
    try:
        f = pdr.get_data_yahoo(companies,start,stop)
        df[companies] = f['Adj Close']  # select the adjusted close price
    except ValueError:
        print(' No data found')

# %%
returns = df.pct_change()
ind = [x for x, _ in enumerate(companies)]

plt.bar(ind, returns.mean(), width=0.9, label='Average of Returns', color='r')
plt.bar(ind, returns.std(), width=0.9, label='Risk of Returns', color='g', bottom=returns.mean())

plt.xticks(ind, companies)
plt.ylabel("Returns Score")
plt.xlabel("Symbols")
plt.legend(loc="upper right")
plt.title('Risk vs Return')
plt.show()

# %%
import lxml
from lxml import html
import requests

# %% [markdown]
# ##### Scraping Yahoo for fundamental stock market data.
# I will be scraping yahoo finance in order to get the fundamental data that I need for my analysis this week.

# %% [markdown]
# https://finance.yahoo.com/quote/  this is the website that I will be scraping. I will then tell it which company I want to look at and scrape the site for their fundamental data. I will be starting with NFLX

# %% [markdown]
# ### Analyzing Working Capital
#
# I used this page for some help with understanding what working capital was: https://www.investopedia.com/terms/w/workingcapital.asp
#
# ##### What is working capital?
# Working capital is difference between a company's current assets and its current liabilities. It can help to measure a comapanies' short-terrm financial health.
# A company with a negative working capital means that the ratio of their current assets to liabilities are less than one.
# A positive working capital means that the company can fund its current operations and can invest in future growth.
# A high working capital does not always mean that it is good. It could mean that the business has too much inventory or it is not investing its excess cash.

# %%
symbol = 'NFLX'

url = 'https://finance.yahoo.com/quote/' + symbol + '/balance-sheet?p=' + symbol

# Set up the request headers that we're going to use, to simulate
# a request by the Chrome browser. 
headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
    'Cache-Control': 'max-age=0',
    'Connection': 'close',
    'DNT': '1', 
    'Pragma': 'no-cache',
    'Referrer': 'https://google.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36'
}

# Fetch the page 
page = requests.get(url, headers=headers)

# Parse the page with LXML,
tree = html.fromstring(page.content)

tree.xpath("//h1/text()")
# Out:
# ['Netflix, Inc. (NFLX)']

# %%
table_rows = tree.xpath("//div[contains(@class, 'D(tbr)')]")

assert len(table_rows) > 0

parsed_rows = []

for table_row in table_rows:
    parsed_row = []
    el = table_row.xpath("./div")
    
    none_count = 0
    
    for rs in el:
        try:
            (text,) = rs.xpath('.//span/text()[1]')
            parsed_row.append(text)
        except ValueError:
            parsed_row.append(np.NaN)
            none_count += 1

    if (none_count < 4):
        parsed_rows.append(parsed_row)

df_netflix = pd.DataFrame(parsed_rows)

# %%
#i am cleaning up the data and making sure that it is in the 
df_netflix = pd.DataFrame(parsed_rows)
df_netflix = df_netflix.set_index(0)
df_netflix = df_netflix.transpose() 

# Rename the "Breakdown" column to "Date"
cols = list(df_netflix.columns)
cols[0] = 'Date'
df_netflix = df_netflix.set_axis(cols, axis='columns', inplace=False)




df_netflix
# Out:
#          Date Total Assets Total Liabilities Net Minority Interest  \
# 1  12/31/2020   39,280,359                              28,215,119
# 2  12/31/2019   33,975,712                              26,393,555
# 3  12/31/2018   25,974,400                              20,735,635
# 4  12/31/2017   19,012,742                              15,430,786
#
#   Total Equity Gross Minority Interest Total Capitalization  \
# 1                           11,065,240           26,874,335
# 2                            7,582,157           22,341,417
# 3                            5,238,765           15,598,823
# 4                            3,581,956           10,081,388
#
#   Common Stock Equity Net Tangible Assets Working Capital Invested Capital  \
# 1          11,065,240         -14,318,710       1,955,795       27,374,213
# 2           7,582,157         -16,922,410        -677,192       22,341,417
# 3           5,238,765          -9,722,189       3,206,815       15,598,823
# ...

# %% [markdown]
# Based on this chart, I can see that back in 2019, Netflix had a negative working capital.

# %% [markdown]
# ###### Net Tangible Assets
#
# Net tangible assets are the total assets of a company minus the intangible assets. It allows people to focus on a firm's physical assets in isolation. It seems that for Netflix they continue to have a negative tangible assets which means that their assets are tied with intangible assets such as goodwill, patents and trademarks.

# %%
symbol = 'COST'

url = 'https://finance.yahoo.com/quote/' + symbol + '/balance-sheet?p=' + symbol

# Set up the request headers that we're going to use, to simulate
# a request by the Chrome browser. 
headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
    'Cache-Control': 'max-age=0',
    'Connection': 'close',
    'DNT': '1', 
    'Pragma': 'no-cache',
    'Referrer': 'https://google.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36'
}

# Fetch the page 
page = requests.get(url, headers=headers)

# Parse the page with LXML,
tree = html.fromstring(page.content)

tree.xpath("//h1/text()")
# Out:
# ['Costco Wholesale Corporation (COST)']

# %%
table_rows = tree.xpath("//div[contains(@class, 'D(tbr)')]")

assert len(table_rows) > 0

parsed_rows = []

for table_row in table_rows:
    parsed_row = []
    el = table_row.xpath("./div")
    
    none_count = 0
    
    for rs in el:
        try:
            (text,) = rs.xpath('.//span/text()[1]')
            parsed_row.append(text)
        except ValueError:
            parsed_row.append(np.NaN)
            none_count += 1

    if (none_count < 4):
        parsed_rows.append(parsed_row)

df_cost = pd.DataFrame(parsed_rows)

# %%
#i am cleaning up the data and making sure that it is in the 
df_cost = pd.DataFrame(parsed_rows)
df_cost = df_cost.set_index(0)
df_cost = df_cost.transpose() 

# Rename the "Breakdown" column to "Date"
cols = list(df_cost.columns)
cols[0] = 'Date'
df_cost = df_cost.set_axis(cols, axis='columns', inplace=False)

df_cost
# Out:
#         Date Total Assets Total Liabilities Net Minority Interest  \
# 1  8/31/2021   59,268,000                              41,190,000
# 2  8/31/2020   55,556,000                              36,851,000
# 3  8/31/2019   45,400,000                              29,816,000
# 4  8/31/2018   40,830,000                              27,727,000
#
#   Total Equity Gross Minority Interest Total Capitalization  \
# 1                           18,078,000           24,256,000
# 2                           18,705,000           25,798,000
# 3                           15,584,000           20,367,000
# 4                           13,103,000           19,286,000
#
#   Common Stock Equity Capital Lease Obligations Net Tangible Assets  \
# 1          17,564,000                 2,642,000          17,564,000
# 2          18,284,000                 2,558,000          18,284,000
# 3          15,243,000                       NaN          15,243,000
# ...

# %% [markdown]
# For Costco it seems that their working capital is a lot lower than in the past 4 years and significantly different than their 2020 working capital.

# %%
symbol = 'HD'

url = 'https://finance.yahoo.com/quote/' + symbol + '/balance-sheet?p=' + symbol

# Set up the request headers that we're going to use, to simulate
# a request by the Chrome browser. 
headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
    'Cache-Control': 'max-age=0',
    'Connection': 'close',
    'DNT': '1', 
    'Pragma': 'no-cache',
    'Referrer': 'https://google.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36'
}

# Fetch the page 
page = requests.get(url, headers=headers)

# Parse the page with LXML,
tree = html.fromstring(page.content)

tree.xpath("//h1/text()")
# Out:
# ['The Home Depot, Inc. (HD)']

# %%
table_rows = tree.xpath("//div[contains(@class, 'D(tbr)')]")

assert len(table_rows) > 0

parsed_rows = []

for table_row in table_rows:
    parsed_row = []
    el = table_row.xpath("./div")
    
    none_count = 0
    
    for rs in el:
        try:
            (text,) = rs.xpath('.//span/text()[1]')
            parsed_row.append(text)
        except ValueError:
            parsed_row.append(np.NaN)
            none_count += 1

    if (none_count < 4):
        parsed_rows.append(parsed_row)

df_hd = pd.DataFrame(parsed_rows)

# %%
#i am cleaning up the data and making sure that it is in the 
df_hd = pd.DataFrame(parsed_rows)
df_hd = df_hd.set_index(0)
df_hd = df_hd.transpose() 

# Rename the "Breakdown" column to "Date"
cols = list(df_cost.columns)
cols[0] = 'Date'
df_hd = df_cost.set_axis(cols, axis='columns', inplace=False)

df_hd
# Out:
#         Date Total Assets Total Liabilities Net Minority Interest  \
# 1  8/31/2021   59,268,000                              41,190,000
# 2  8/31/2020   55,556,000                              36,851,000
# 3  8/31/2019   45,400,000                              29,816,000
# 4  8/31/2018   40,830,000                              27,727,000
#
#   Total Equity Gross Minority Interest Total Capitalization  \
# 1                           18,078,000           24,256,000
# 2                           18,705,000           25,798,000
# 3                           15,584,000           20,367,000
# 4                           13,103,000           19,286,000
#
#   Common Stock Equity Capital Lease Obligations Net Tangible Assets  \
# 1          17,564,000                 2,642,000          17,564,000
# 2          18,284,000                 2,558,000          18,284,000
# 3          15,243,000                       NaN          15,243,000
# ...

# %% [markdown]
# For home depot it seems that they have a pretty similar working capital yearly, the exception being 2020.

# %%
symbol = 'ETSY'

url = 'https://finance.yahoo.com/quote/' + symbol + '/balance-sheet?p=' + symbol

# Set up the request headers that we're going to use, to simulate
# a request by the Chrome browser. 
headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
    'Cache-Control': 'max-age=0',
    'Connection': 'close',
    'DNT': '1', 
    'Pragma': 'no-cache',
    'Referrer': 'https://google.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36'
}

# Fetch the page 
page = requests.get(url, headers=headers)

# Parse the page with LXML,
tree = html.fromstring(page.content)

tree.xpath("//h1/text()")
# Out:
# ['Etsy, Inc. (ETSY)']

# %%
table_rows = tree.xpath("//div[contains(@class, 'D(tbr)')]")

assert len(table_rows) > 0

parsed_rows = []

for table_row in table_rows:
    parsed_row = []
    el = table_row.xpath("./div")
    
    none_count = 0
    
    for rs in el:
        try:
            (text,) = rs.xpath('.//span/text()[1]')
            parsed_row.append(text)
        except ValueError:
            parsed_row.append(np.NaN)
            none_count += 1

    if (none_count < 4):
        parsed_rows.append(parsed_row)

df_etsy = pd.DataFrame(parsed_rows)

# %%
#i am cleaning up the data and making sure that it is in the 
df_etsy = pd.DataFrame(parsed_rows)
df_etsy = df_etsy.set_index(0)
df_etsy = df_etsy.transpose() 

# Rename the "Breakdown" column to "Date"
cols = list(df_cost.columns)
cols[0] = 'Date'
df_etsy = df_cost.set_axis(cols, axis='columns', inplace=False)

df_etsy
# Out:
#         Date Total Assets Total Liabilities Net Minority Interest  \
# 1  8/31/2021   59,268,000                              41,190,000
# 2  8/31/2020   55,556,000                              36,851,000
# 3  8/31/2019   45,400,000                              29,816,000
# 4  8/31/2018   40,830,000                              27,727,000
#
#   Total Equity Gross Minority Interest Total Capitalization  \
# 1                           18,078,000           24,256,000
# 2                           18,705,000           25,798,000
# 3                           15,584,000           20,367,000
# 4                           13,103,000           19,286,000
#
#   Common Stock Equity Capital Lease Obligations Net Tangible Assets  \
# 1          17,564,000                 2,642,000          17,564,000
# 2          18,284,000                 2,558,000          18,284,000
# 3          15,243,000                       NaN          15,243,000
# ...

# %% [markdown]
# ##### Week 2 Summary

# %% [markdown]
# | Symbol | Description | Current Price | Purchase Price | QTY | Total Value |
# |:--- |: --- |: --- |: --- |: --- |: --- |
# | COST | Costco Wholesale Corp | 533.60 | 526.70 | 100 | 54613.00|
# | ETSY | Etsy, Inc | 291.38 | 291.38| 20 | 5827.60|
# | HD | Home Depot, Inc | 665.64 | 693.86 | 18 | 11981.52 |
# | NFLX | NetFlix Inc | 678.97 | 693.86 | 18 | 12,221.37 |
# | VGT | Vannguard Group, Inc- Vanguard Information Technology ETF  | 457.94 | 451.65 | 100 | 45,794.00 |
# | VOO | CVannguard Group, Inc-Vanguard S&P 500 ETF | 431.96 | 5432.54 | 20 | 8,639.20 |
#
#
# Total: $133,130.92

# %% [markdown]
# # Week 3

# %% [markdown]
# I will be starting my week 3 analysis with a recap with every trade that I made.

# %% [markdown]
# The first trade that I made was purchasing 20 shares of APPL because it was going down at the time that I made the trade. I wanted to buy APPL since this project first started but everytime that I checked on it, it was always going up. I finally bought it as it was going down so I bought the shares at a lower price. Today, Thursday, I checked APPL again and I saw that it was lower than on Wednesday so I decided to purchase 30 more shares.

# %% [markdown]
# My second trade was to buy 20 more shares of VOO. I have realized that these past two weeks, my ETF shares always bring in some profit. It is not always climbing up too fast but when it does drop it does not drop as significantly as my other shares.

# %%
#importing some more libraries for this weeks analysis
import pandas_datareader as web

# %%
companies = ['AAPL', 'COST', 'ETSY', 'HD', 'NFLX', 'VGT', 'VOO']
my_stock = web.get_data_yahoo(companies, start = "2018-11-17", end = "2021-11-17")

# %%
fig = plt.figure()
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)
ax6 = fig.add_subplot(326)
# ax7 = fig.add_subplot(327)
ax1.plot(my_stock['Adj Close']['AAPL'])
ax1.set_title("Apple, Inc")
ax2.plot(my_stock['Adj Close']['COST'])
ax2.set_title("Costco")
ax3.plot(my_stock['Adj Close']['ETSY'])
ax3.set_title("Etsy Inc")
ax4.plot(my_stock['Adj Close']['HD'])
ax4.set_title("Home Depot")
ax5.plot(my_stock['Adj Close']['NFLX'])
ax5.set_title("Netflix")
ax6.plot(my_stock['Adj Close']['VGT'])
ax6.set_title("VGT")
# ax7.plot(my_stock['Adj Close']['VOO'])
# ax7.set_title("VOO")

plt.tight_layout()
plt.show()

# %% [markdown]
# In the graphs above I was only able to add an even number of graphs so I could not include VOO. Here I am charting the stock prices for 6/7 of my stocks.

# %% [markdown]
# Next I will be calculating the returns for these stocks.

# %%
my_stock_returns = my_stock['Adj Close'].pct_change()
my_stock_monthly_returns = my_stock['Adj Close'].resample('M').ffill().pct_change()

# %%
fit = plt.figure()
(my_stock_monthly_returns +1).cumprod().plot()
plt.show()

# %% [markdown]
# ##### What my graph shows
#
# Based on the above graph I can see that Etsy currently has the best returns and that VOO has the worst returns. This is great knowledge for me to have when making my trades for next week. Out of my two ETFs that I have, VOO is underperforming and VGT is performing better than other companies.

# %% [markdown]
# #### Diversification
# One thing I really wanted to do with this project was include diversification. Diversification is a risk management strategy that mixes a wide variety of investments within a portfolia. I did not just want invest everything in tech companies even thought they are prone to doing fairly well. Diversification includes ETFs because they are a marketable basket of securities that follow a sector. In this case VGT follows Information Technology stocks. It also hedges against market volatility and offer a higher return long term. Although it does not help with short term gains, it is better for long term returns.

# %% [markdown]
# Moving on from diversification I wanted to see the distribution of my stocks. THis will be very helpful for next weeks trade decisions.

# %%
my_stock.hist(bins=50, figsize=(20, 15))
plt.show()

# %% [markdown]
# # Week 4
# Since this will be my last analysis I figured I would try out some different techniques that my peers used this semester. I saw the monte carlo simulation talked about quite a bit so I will begin here. I do not have any prior knowledge of this simulation so I am very excited to learn about it!

# %% [markdown]
# I used this site: https://www.investopedia.com/terms/m/montecarlosimulation.asp for some help with understanding what this simulation was and how it can help me.

# %% [markdown]
# This is how it is defined: Monte Carlo Simulation is used to model the probability of different outcomes in a process that cannot easily be predicted due to the intervention of random variables.
# - It can help to predict the probability of different outcomes
# - It can help to explain the impact of risk and uncertainty in prediction models

# %%
from pandas_datareader import data as wb
import seaborn as sns 
from scipy.stats import norm 
import matplotlib.pyplot as mplt

symbols = ['AAPL', 'COST', 'ETSY', 'HD', 'NFLX', 'VGT', 'VOO']
data = pd.DataFrame()
for sym in symbols:
    data[sym] = wb.DataReader(sym, data_source ='yahoo', start = '2020-12-5')['Adj Close']
    
data.head()
# Out:
#                   AAPL        COST        ETSY          HD        NFLX  \
# Date
# 2020-12-07  122.991783  370.502838  156.929993  257.265533  515.780029
# 2020-12-08  123.617920  374.740509  163.970001  256.364349  512.659973
# 2020-12-09  121.033844  371.455566  159.229996  260.145355  493.600006
# 2020-12-10  122.484901  369.966949  165.300003  259.391144  501.089996
# 2020-12-11  121.659996  372.259430  170.020004  259.136414  503.220001
#
#                    VGT         VOO
# Date
# 2020-12-07  339.998230  334.377167
# 2020-12-08  341.536713  335.343292
# 2020-12-09  334.529358  332.366058
# 2020-12-10  336.008209  332.208344
# 2020-12-11  335.412689  331.784393

# %%
data.plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Here I am computing the logarithmic returns of my stocks

# %%
log_return = np.log(1 + data.pct_change())

sns.displot(log_return.iloc[1:])
plt.xlabel("Daily Returns")
plt.ylabel("Frequency")
# Out:
# Text(15.953263888888884, 0.5, 'Frequency')

# %% [markdown]
# Next I will be calculating the drift. The drift is the direction that rates of returns have had in the past.

# %%
returns = data.pct_change()
returns.dropna(inplace=True)
returns.head()
# Out:
#                 AAPL      COST      ETSY        HD      NFLX       VGT  \
# Date
# 2020-12-08  0.005091  0.011438  0.044861 -0.003503 -0.006049  0.004525
# 2020-12-09 -0.020904 -0.008766 -0.028908  0.014749 -0.037179 -0.020517
# 2020-12-10  0.011989 -0.004008  0.038121 -0.002899  0.015174  0.004421
# 2020-12-11 -0.006735  0.006196  0.028554 -0.000982  0.004251 -0.001772
# 2020-12-14 -0.005147 -0.001919 -0.000294  0.003893  0.038154  0.004291
#
#                  VOO
# Date
# 2020-12-08  0.002889
# 2020-12-09 -0.008878
# 2020-12-10 -0.000475
# 2020-12-11 -0.001276
# 2020-12-14 -0.004576

# %% [markdown]
# Next I will be working with variance eand daily returns which can help with the voltality of my shares

# %%
def mont_car(symbol):
    days = 7
    trials = 20

    mean = returns.mean()[symbol]
    var = returns.var()[symbol]
    std = returns.std()[symbol]
    drift = mean - (0.5*var)

    
    Z = norm.ppf(np.random.rand(days, trials))
    daily_returns = np.exp(drift + std * Z)
    

    price_paths = np.zeros_like(daily_returns)
    price_paths[0] = data[symbol].iloc[-1]
    for t in range(1, days):
        price_paths[t] = price_paths[t-1]*daily_returns[t]
    mplt.plot(price_paths)

# %%
mont_car('AAPL')

# %%
mont_car('COST')

# %%
mont_car('ETSY')

# %%
mont_car('HD')

# %%
mont_car('NFLX')

# %%
mont_car('VGT')

# %%
mont_car('VOO')

# %% [markdown]
# Based on this analysis it seems that in that next 6 days AAPL, COST, NFLX, and VGT will increase. This week has been terrible for my stocks and this insight will help me with selling some of these shares this week.

# %% [markdown]
# ##### A few days later
# I did the monte carlo simultion analysis on Monday 12/6 and now it is Thursday 12/9.
# On Wednesday I saw that AAPL was going for more than what I bought it for so I sold 25 of my shares and I sold 20 of my VOO shares. Today I decided to buy more VGT since I do end up getting the most profit for this company

# %% [markdown]
# | Symbol | Description | Current Price | Purchase Price | QTY | Total Value |
# |:--- |: --- |: --- |: --- |: --- |: --- |
# | AAPL | Apple Inc | 175.53 | 165.71 | 25 | 4,388.25|
# | COST | Costco Wholesale Corp | 533.60 | 526.70 | 100 | 52,648|
# | ETSY | Etsy, Inc | 291.38 | 291.38| 20 | 4,757.60|
# | HD | Home Depot, Inc | 665.64 | 693.86 | 18 | 8,230.67 |
# | NFLX | NetFlix Inc | 678.97 | 693.86 | 18 | 11,108.43 |
# | VGT | Vannguard Group, Inc- Vanguard Information Technology ETF  | 457.94 | 451.65 | 100 | 68,394 |
# | VOO | CVannguard Group, Inc-Vanguard S&P 500 ETF | 431.96 | 5432.54 | 20 | 8,616.80 |
